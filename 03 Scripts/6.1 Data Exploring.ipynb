# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Upload Data Set
df = pd.read_csv(r'C:\Users\Owner\Documents\Chocolate Bar Analysis\02 Data\Original Data\Chocolate_bar_ratings.csv', index_col = False)

# %%
df.head()
# Out:
#     ref      manufacturer company_location  review_date  \
# 0  1776  Forteza (Cortes)      Puerto Rico         2016
# 1  1776  Forteza (Cortes)      Puerto Rico         2016
# 2  1992     Alain Ducasse           France         2017
# 3  1215     Alain Ducasse           France         2014
# 4   741       Grand Place          Vietnam         2011
#
#   country_of_bean_origin specific_bean_origin cocoa_percent  \
# 0     Dominican Republic          Puerto Rico           80%
# 1     Dominican Republic   Dominican Republic           70%
# 2                 Mexico   Porcelana, Mexique           75%
# 3               Trinidad              Trinite           65%
# 4                Vietnam    Ben Tre, Dong Nai           72%
#
#    number_of_ingredients   ingredients                characteristics  rating
# 0                      6  B,S,C,V,L,Sa     vanilla, dried fruit, nuts    2.75
# 1                      6  B,S,C,V,L,Sa  strong vanilla, earthy, nutty    2.75
# ...

# %%
df.tail()
# Out:
#        ref                manufacturer company_location  review_date  \
# 2496  1113  Hotel Chocolat (Coppeneur)             U.K.         2013
# 2497  1760                        Ocho      New Zealand         2016
# 2498  1185                     C-Amaro            Italy         2013
# 2499  1506                      Sirene           Canada         2015
# 2500  1502                      Sirene           Canada         2015
#
#      country_of_bean_origin                            specific_bean_origin  \
# 2496                Ecuador  Los Rios, H. Iara, 2012, 120hr c., batch 13092
# 2497                  Samoa                                   Sang Yum Coop
# 2498                Ecuador                                         Ecuador
# 2499                Ecuador            Camino Verde P., Balao, Guayas, 2012
# 2500             Madagascar                          Somia Plantation, 2012
#
#      cocoa_percent  number_of_ingredients ingredients  \
# ...

# %%
df.shape
# Out:
# (2501, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2501 entries, 0 to 2500
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ref                     2501 non-null   int64
#  1   manufacturer            2501 non-null   object
#  2   company_location        2501 non-null   object
#  3   review_date             2501 non-null   int64
#  4   country_of_bean_origin  2501 non-null   object
#  5   specific_bean_origin    2501 non-null   object
#  6   cocoa_percent           2501 non-null   object
#  7   number_of_ingredients   2501 non-null   int64
#  8   ingredients             2501 non-null   object
#  9   characteristics         2501 non-null   object
#  10  rating                  2501 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 215.1+ KB

# %%
df.dtypes
# Out:
# ref                         int64
# manufacturer               object
# company_location           object
# review_date                 int64
# country_of_bean_origin     object
# specific_bean_origin       object
# cocoa_percent              object
# number_of_ingredients       int64
# ingredients                object
# characteristics            object
# rating                    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['ref', 'manufacturer', 'company_location', 'review_date',
#        'country_of_bean_origin', 'specific_bean_origin', 'cocoa_percent',
#        'number_of_ingredients', 'ingredients', 'characteristics', 'rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#                ref  review_date  number_of_ingredients       rating
# count  2501.000000  2501.000000            2501.000000  2501.000000
# mean   1481.423431  2014.660136               3.035186     3.211815
# std     771.528406     4.071615               0.909264     0.427366
# min       5.000000  2006.000000               1.000000     1.000000
# 25%     863.000000  2012.000000               2.000000     3.000000
# 50%    1502.000000  2015.000000               3.000000     3.250000
# 75%    2142.000000  2018.000000               4.000000     3.500000
# max    2768.000000  2022.000000               6.000000     4.000000
